# %% [markdown]
# # TUPLES

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# - Immutable, you cannot directly add, remove, or modify elements like you would with lists.
# - used to store collection of related stuff.
# - tuple can be unpacked individually

# %%
# Deleting a Tuple
 
Tuple1 = (0, 1, 2, 3, 4)
del Tuple1
 
#print(Tuple1)

"""
---------------------------------------------------------------------------
NameError                                 Traceback (most recent call last)
~\AppData\Local\Temp\ipykernel_19604\284796215.py in <module>
      4 del Tuple1
      5 
----> 6 print(Tuple1)

NameError: name 'Tuple1' is not defined
"""
# Out:
# "\n---------------------------------------------------------------------------\nNameError                                 Traceback (most recent call last)\n~\\AppData\\Local\\Temp\\ipykernel_19604\x0284796215.py in <module>\n      4 del Tuple1\n      5 \n----> 6 print(Tuple1)\n\nNameError: name 'Tuple1' is not defined\n"

# %% [markdown]
# ### """error message will be displayed since tuple1 doesn't exist"""

# %% [markdown]
# Mutable vs. Immutable Methods:
#
# - For lists, there are methods that modify the list in place, such as append(), extend(), insert(), remove(), and pop().
# - Since tuples are immutable, they lack these methods, and operations like adding or removing elements are not possible after creation.

# %% [markdown]
# #### When to use Tuples
# You may be wondering, "Why bother using tuples when they have fewer available methods?" To be honest, tuples are not used as often as lists in programming, but are used when immutability is necessary. If in your program you are passing around an object and need to make sure it does not get changed, then a tuple becomes your solution. It provides a convenient source of data integrity.
